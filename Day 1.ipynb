# %%
import pandas as pd

# %%
data = pd.read_csv("day1_vals.csv", header = None)

# %%
numbers = list(data.loc[0:][0])

# %%
numbers = sorted(numbers, reverse = True)

# %%
for number in numbers:
    remainder1 = 2020 - number
    if remainder in numbers:
        print(number)
        print(remainder)
        print(number * remainder)
# Out:
# 1131
# 889
# 1005459
# 889
# 1131
# 1005459

# %%
numbers = sorted(numbers, reverse = False)
for number in numbers:
    remainder1 = 2020 - number
    for number2 in numbers:
        remainder2 = remainder1 - number2
        if remainder2 in numbers and (number + number2 + remainder2 == 2020):
            print(number * number2 * remainder2)
# Out:
# 92643264
# 92643264
# 92643264
# 92643264
# 92643264
# 92643264

# %%
numbers
# Out:
# [112,
#  210,
#  666,
#  760,
#  820,
#  831,
#  860,
#  889,
#  978,
#  1022,
#  1117,
#  1131,
#  1225,
#  1242,
#  1251,
#  1257,
#  1263,
#  1265,
#  1266,
#  1276,
#  1278,
#  1284,
#  1285,
#  1286,
#  1307,
#  1310,
#  1314,
#  1315,
#  1317,
#  1319,
#  1321,
#  1325,
#  1326,
#  1330,
#  1343,
#  1351,
#  1358,
#  1364,
#  1365,
#  1366,
#  1368,
#  1374,
#  1378,
#  1381,
#  1387,
#  1391,
#  1397,
#  1410,
#  1419,
#  1451,
#  1454,
#  1460,
#  1463,
#  1467,
#  1476,
#  1480,
#  1482,
#  1485,
#  1492,
#  1499,
#  1516,
#  1520,
#  1530,
#  1571,
#  1574,
#  1576,
#  1578,
#  1581,
#  1584,
#  1588,
#  1594,
#  1606,
#  1616,
#  1618,
#  1620,
#  1623,
#  1632,
#  1642,
#  1678,
#  1686,
#  1689,
#  1699,
#  1702,
#  1708,
#  1709,
#  1715,
#  1718,
#  1721,
#  1731,
#  1734,
#  1740,
#  1753,
#  1765,
#  1784,
#  1794,
#  1797,
#  1803,
#  1806,
#  1808,
#  1809,
#  1812,
#  1813,
#  1815,
#  1818,
#  1819,
#  1821,
#  1822,
#  1825,
#  1827,
#  1828,
#  1830,
#  1832,
# ...
